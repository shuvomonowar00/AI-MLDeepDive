# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvomonowar00/AI-MLDeepDive/blob/main/learn-libraries-and-frameworks/learn-numpy/numpy_fundamentals_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mastering NumPy**

# %%
# Check that wheather NumPy is installed or not
try:
    import numpy as np
    print("NumPy is installed.")
    print(f"NumPy version: {np.__version__}")
except ImportError:
    print("NumPy is not installed.")
# Out:
# NumPy is installed.
# NumPy version: 2.0.2

# %%
arr = [1, 2, 3, 4, 5]
new_arr = np.array(arr)

print(new_arr.ndim)
print(new_arr.dtype)
# Out:
# 1

# %%
# Find the mean
# import numpy as np

# Sample Data
arr = [5, 6, 11]

# Mean
mean = np.mean(arr)

print("Mean = ", mean)
# Out:
# Mean =  7.333333333333333
